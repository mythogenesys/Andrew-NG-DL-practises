# %% [markdown]
# <a href="https://colab.research.google.com/github/mythogenesys/Andrew-NG-DL-practises/blob/main/EEG_Generalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
#      FINAL & VERIFIED: STPC EEG Research Hub (All Phases)
# ==============================================================================
# This notebook runs all three phases of the EEG study using the new,
# refactored `run_training.py` and `run_validation.py` scripts. It includes
# all necessary environment and library fixes for reproducibility on Colab.
# ==============================================================================
import os
from google.colab import drive
from IPython.display import Image, display

# ---
# [Step 1/3] SETUP: Mount Drive & Navigate to Project
# ---
print("--- [Step 1/3] Setting up the environment ---")
drive.mount('/content/drive')
PROJECT_DIR = "/content/ecg-denoiser-hackathon"
if not os.path.exists(PROJECT_DIR):
    print("Cloning repository...")
    # !git clone -q https://github.com/Mohan-CAS-and-hackathons/ecg-denoiser-hackathon.git {PROJECT_DIR}
os.chdir(PROJECT_DIR)
print(f"✅ Current directory: {os.getcwd()}")
print("Pulling latest changes from repository...")
# !git pull -q
# Out:
# --- [Step 1/3] Setting up the environment ---
# Mounted at /content/drive
# Cloning repository...
# ✅ Current directory: /content/ecg-denoiser-hackathon
# Pulling latest changes from repository...

# %%
# ---
# [Step 2/3] ENVIRONMENT & TRAINING: Install dependencies and train all models
# ---
print("\n--- [Step 2/3] Installing dependencies and training EEG models ---")



# Now install all other requirements
print("Installing other required packages...")
# !pip install -q -r requirements.txt


# First, install the stable wfdb version to prevent any conflicts
print("Installing a known-stable version of wfdb...")
# !pip uninstall -y wfdb
# !pip install --upgrade -q wfdb
# Out:
# --- [Step 2/3] Installing dependencies and training EEG models ---
# Installing other required packages...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 114.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 78.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 100.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 135.7 MB/s eta 0:00:00
# Installing a known-stable version of wfdb...
# Found existing installation: wfdb 4.1.2
# Uninstalling wfdb-4.1.2:
#   Successfully uninstalled wfdb-4.1.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 76.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.

# %%
# --- Define All Necessary Paths ---
DRIVE_BASE_PATH = '/content/drive/MyDrive/ecg_denoiser_hackathon/'
DATA_DIR_EEG = os.path.join(DRIVE_BASE_PATH, 'data/chb-mit-scalp-eeg-database-1.0.0')
MODEL_DIR = os.path.join(DRIVE_BASE_PATH, 'models2')
RESULTS_DIR = os.path.join(DRIVE_BASE_PATH, 'results2')
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# --- Model Paths ---
MODEL_PATH_EEG_BASELINE = os.path.join(MODEL_DIR, 'eeg_denoiser_baseline_refactored.pth')
MODEL_PATH_EEG_SPATIAL = os.path.join(MODEL_DIR, 'eeg_denoiser_spatial_refactored.pth')
MODEL_PATH_EEG_FREQ = os.path.join(MODEL_DIR, 'eeg_denoiser_frequency_refactored.pth')
MODEL_PATH_EEG_SS = os.path.join(MODEL_DIR, 'eeg_denoiser_self_supervised_refactored.pth')

# --- Train EEG Models Sequentially ---
print("\n--- Training EEG Baseline Model (Phase 1) ---")
# !python3 src/experiments/run_training.py eeg --eeg_experiment_type baseline \
    --data_dir "{DATA_DIR_EEG}" --save_path "{MODEL_PATH_EEG_BASELINE}" --epochs 10

print("\n--- Training EEG Spatial Model (Phase 1) ---")
# !python3 src/experiments/run_training.py eeg --eeg_experiment_type spatial \
    --data_dir "{DATA_DIR_EEG}" --save_path "{MODEL_PATH_EEG_SPATIAL}" --epochs 10
# Out:
# --- Training EEG Baseline Model (Phase 1) ---
# --- Training EEG Model ---
# Experiment Type: baseline
# Scanning for common channels and loading all EEG segments...
# Finding Common Channels:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels:  14% 1/7 [00:00<00:04,  1.20it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels: 100% 7/7 [00:00<00:00,  7.69it/s]
# Found 23 common channels across all records.
# Processing files:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  14% 1/7 [00:04<00:24,  4.16s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  29% 2/7 [00:06<00:16,  3.20s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  43% 3/7 [00:09<00:11,  2.83s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  57% 4/7 [00:11<00:07,  2.48s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  71% 5/7 [00:13<00:04,  2.33s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  86% 6/7 [00:15<00:02,  2.22s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files: 100% 7/7 [00:15<00:00,  2.21s/it]
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:220: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda'))
# Epoch 1/10: 100% 313/313 [00:10<00:00, 31.04it/s, loss=0.291]
# Epoch 2/10: 100% 313/313 [00:08<00:00, 36.91it/s, loss=0.361]
# Epoch 3/10: 100% 313/313 [00:07<00:00, 43.81it/s, loss=0.239]
# Epoch 4/10: 100% 313/313 [00:08<00:00, 37.32it/s, loss=0.235]
# Epoch 5/10: 100% 313/313 [00:07<00:00, 44.18it/s, loss=0.242]
# Epoch 6/10: 100% 313/313 [00:09<00:00, 31.95it/s, loss=0.349]
# Epoch 7/10: 100% 313/313 [00:09<00:00, 32.49it/s, loss=0.215]
# Epoch 8/10: 100% 313/313 [00:07<00:00, 44.02it/s, loss=0.205]
# Epoch 9/10: 100% 313/313 [00:08<00:00, 37.37it/s, loss=0.252]
# Epoch 10/10: 100% 313/313 [00:08<00:00, 35.86it/s, loss=0.265]
# EEG model saved to /content/drive/MyDrive/ecg_denoiser_hackathon/models2/eeg_denoiser_baseline_refactored.pth
#
# --- Training EEG Spatial Model (Phase 1) ---
# --- Training EEG Model ---
# Experiment Type: spatial
# Scanning for common channels and loading all EEG segments...
# Finding Common Channels:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels:  14% 1/7 [00:00<00:02,  2.37it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels: 100% 7/7 [00:00<00:00, 14.82it/s]
# Found 23 common channels across all records.
# Processing files:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  14% 1/7 [00:02<00:15,  2.60s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  29% 2/7 [00:05<00:13,  2.78s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  43% 3/7 [00:08<00:11,  2.80s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  57% 4/7 [00:10<00:07,  2.48s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  71% 5/7 [00:12<00:04,  2.31s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  86% 6/7 [00:14<00:02,  2.19s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files: 100% 7/7 [00:14<00:00,  2.09s/it]
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:220: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda'))
# Epoch 1/10: 100% 313/313 [00:12<00:00, 25.50it/s, loss=0.482]
# Epoch 2/10: 100% 313/313 [00:10<00:00, 29.98it/s, loss=0.501]
# Epoch 3/10: 100% 313/313 [00:10<00:00, 29.13it/s, loss=0.382]
# Epoch 4/10: 100% 313/313 [00:09<00:00, 32.22it/s, loss=0.454]
# Epoch 5/10: 100% 313/313 [00:10<00:00, 29.61it/s, loss=0.337]
# Epoch 6/10: 100% 313/313 [00:11<00:00, 28.39it/s, loss=0.353]
# Epoch 7/10: 100% 313/313 [00:10<00:00, 30.27it/s, loss=0.387]
# Epoch 8/10: 100% 313/313 [00:10<00:00, 29.69it/s, loss=0.367]
# Epoch 9/10: 100% 313/313 [00:09<00:00, 31.81it/s, loss=0.411]
# Epoch 10/10: 100% 313/313 [00:09<00:00, 32.35it/s, loss=0.383]
# EEG model saved to /content/drive/MyDrive/ecg_denoiser_hackathon/models2/eeg_denoiser_spatial_refactored.pth

# %%
print("\n--- Training EEG Frequency Model (Phase 2) ---")
# !python3 src/experiments/run_training.py eeg --eeg_experiment_type frequency \
    --data_dir "{DATA_DIR_EEG}" --save_path "{MODEL_PATH_EEG_FREQ}" --epochs 10

print("\n--- Training EEG Self-Supervised Model (Phase 3) ---")
# !python3 src/experiments/run_training.py eeg --eeg_experiment_type self_supervised \
    --data_dir "{DATA_DIR_EEG}" --save_path "{MODEL_PATH_EEG_SS}" --epochs 20

print("\n✅ All EEG model training complete!")
# Out:
# --- Training EEG Frequency Model (Phase 2) ---
# --- Training EEG Model ---
# Experiment Type: frequency
# Scanning for common channels and loading all EEG segments...
# Finding Common Channels:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels:  14% 1/7 [00:00<00:03,  1.65it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels: 100% 7/7 [00:00<00:00, 10.31it/s]
# Found 23 common channels across all records.
# Processing files:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  14% 1/7 [00:02<00:15,  2.67s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  29% 2/7 [00:04<00:11,  2.22s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  43% 3/7 [00:06<00:08,  2.08s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  57% 4/7 [00:08<00:06,  2.02s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  71% 5/7 [00:10<00:03,  1.99s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  86% 6/7 [00:12<00:02,  2.11s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files: 100% 7/7 [00:13<00:00,  1.89s/it]
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:220: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda'))
# Epoch 1/10:   0% 0/313 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/losses.py:75: UserWarning: ComplexHalf support is experimental and many operators don't support it yet. (Triggered internally at /pytorch/aten/src/ATen/EmptyTensor.cpp:55.)
#   mag_p = torch.abs(torch.fft.rfft(pred, dim=-1))
# Epoch 1/10: 100% 313/313 [00:09<00:00, 33.62it/s, loss=2.05]
# Epoch 2/10: 100% 313/313 [00:08<00:00, 36.32it/s, loss=1.49]
# Epoch 3/10: 100% 313/313 [00:08<00:00, 38.04it/s, loss=1.37]
# Epoch 4/10: 100% 313/313 [00:07<00:00, 41.59it/s, loss=1.77]
# Epoch 5/10: 100% 313/313 [00:08<00:00, 35.69it/s, loss=1.5]
# Epoch 6/10: 100% 313/313 [00:07<00:00, 43.64it/s, loss=1.34]
# Epoch 7/10: 100% 313/313 [00:08<00:00, 36.04it/s, loss=1.34]
# Epoch 8/10: 100% 313/313 [00:08<00:00, 37.34it/s, loss=1.43]
# Epoch 9/10: 100% 313/313 [00:07<00:00, 41.86it/s, loss=1.33]
# Epoch 10/10: 100% 313/313 [00:08<00:00, 37.39it/s, loss=1.39]
# EEG model saved to /content/drive/MyDrive/ecg_denoiser_hackathon/models2/eeg_denoiser_frequency_refactored.pth
#
# --- Training EEG Self-Supervised Model (Phase 3) ---
# --- Training EEG Model ---
# Experiment Type: self_supervised
# Scanning for common channels and loading all EEG segments...
# Finding Common Channels:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels:  14% 1/7 [00:00<00:02,  2.37it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:188: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels: 100% 7/7 [00:00<00:00, 14.71it/s]
# Found 23 common channels across all records.
# Processing files:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  14% 1/7 [00:02<00:16,  2.77s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  29% 2/7 [00:06<00:16,  3.28s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  43% 3/7 [00:08<00:10,  2.72s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  57% 4/7 [00:10<00:07,  2.43s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  71% 5/7 [00:12<00:04,  2.27s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files:  86% 6/7 [00:14<00:02,  2.16s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:13: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
# Processing files: 100% 7/7 [00:14<00:00,  2.11s/it]
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:220: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda'))
# Epoch 1/20: 100% 313/313 [00:11<00:00, 28.24it/s, loss=0.428]
# Epoch 2/20: 100% 313/313 [00:10<00:00, 28.61it/s, loss=0.337]
# Epoch 3/20: 100% 313/313 [00:10<00:00, 29.52it/s, loss=0.345]
# Epoch 4/20: 100% 313/313 [00:11<00:00, 28.24it/s, loss=0.416]
# Epoch 5/20: 100% 313/313 [00:11<00:00, 27.80it/s, loss=0.282]
# Epoch 6/20: 100% 313/313 [00:16<00:00, 19.07it/s, loss=0.318]
# Epoch 7/20: 100% 313/313 [00:16<00:00, 19.25it/s, loss=0.242]
# Epoch 8/20: 100% 313/313 [00:11<00:00, 26.59it/s, loss=0.27]
# Epoch 9/20: 100% 313/313 [00:10<00:00, 28.99it/s, loss=0.255]
# Epoch 10/20: 100% 313/313 [00:09<00:00, 31.94it/s, loss=0.243]
# Epoch 11/20: 100% 313/313 [00:10<00:00, 28.51it/s, loss=0.23]
# Epoch 12/20: 100% 313/313 [00:10<00:00, 29.11it/s, loss=0.251]
# Epoch 13/20: 100% 313/313 [00:11<00:00, 27.85it/s, loss=0.235]
# Epoch 14/20: 100% 313/313 [00:10<00:00, 28.78it/s, loss=0.24]
# Epoch 15/20: 100% 313/313 [00:10<00:00, 30.98it/s, loss=0.329]
# Epoch 16/20: 100% 313/313 [00:10<00:00, 29.17it/s, loss=0.199]
# Epoch 17/20: 100% 313/313 [00:11<00:00, 27.66it/s, loss=0.239]
# Epoch 18/20: 100% 313/313 [00:10<00:00, 29.12it/s, loss=0.255]
# Epoch 19/20: 100% 313/313 [00:10<00:00, 28.65it/s, loss=0.245]
# Epoch 20/20: 100% 313/313 [00:10<00:00, 29.60it/s, loss=0.199]
# EEG model saved to /content/drive/MyDrive/ecg_denoiser_hackathon/models2/eeg_denoiser_self_supervised_refactored.pth
#
# ✅ All EEG model training complete!

# %%
print("\n--- Training EEG Self-Supervised Model (Phase 3) ---")
# !python3 src/experiments/run_training.py eeg --eeg_experiment_type self_supervised \
    --data_dir "{DATA_DIR_EEG}" --save_path "{MODEL_PATH_EEG_SS}" --epochs 20

print("\n✅ All EEG model training complete!")
# Out:
# --- Training EEG Self-Supervised Model (Phase 3) ---
# --- Training EEG Model ---
# Experiment Type: self_supervised
# Scanning for common channels and loading all EEG segments...
# Finding Common Channels:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels:  14% 1/7 [00:00<00:02,  2.32it/s]/content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:186: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=False, verbose=False)
# Finding Common Channels: 100% 7/7 [00:00<00:00, 14.10it/s]
# Found 23 common channels across all records.
# Processing files:   0% 0/7 [00:00<?, ?it/s]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  14% 1/7 [00:03<00:18,  3.06s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  29% 2/7 [00:05<00:12,  2.45s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  43% 3/7 [00:06<00:08,  2.19s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  57% 4/7 [00:08<00:06,  2.06s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  71% 5/7 [00:10<00:04,  2.01s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files:  86% 6/7 [00:12<00:02,  2.00s/it]/content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Processing files: 100% 7/7 [00:13<00:00,  1.87s/it]
# /content/ecg-denoiser-hackathon/src/experiments/run_training.py:222: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda'))
# Epoch 1/20: 100% 313/313 [00:11<00:00, 28.03it/s, loss=0.524]
# Epoch 2/20: 100% 313/313 [00:10<00:00, 28.76it/s, loss=0.468]
# Epoch 3/20: 100% 313/313 [00:11<00:00, 26.99it/s, loss=0.333]
# Epoch 4/20: 100% 313/313 [00:12<00:00, 25.54it/s, loss=0.247]
# Epoch 5/20: 100% 313/313 [00:11<00:00, 26.75it/s, loss=0.305]
# Epoch 6/20: 100% 313/313 [00:10<00:00, 29.44it/s, loss=0.232]
# Epoch 7/20: 100% 313/313 [00:10<00:00, 29.41it/s, loss=0.274]
# Epoch 8/20: 100% 313/313 [00:10<00:00, 29.07it/s, loss=0.334]
# Epoch 9/20: 100% 313/313 [00:11<00:00, 27.66it/s, loss=0.256]
# Epoch 10/20: 100% 313/313 [00:10<00:00, 28.88it/s, loss=0.443]
# Epoch 11/20: 100% 313/313 [00:10<00:00, 29.51it/s, loss=0.22]
# Epoch 12/20: 100% 313/313 [00:09<00:00, 31.76it/s, loss=0.253]
# Epoch 13/20: 100% 313/313 [00:10<00:00, 29.13it/s, loss=0.264]
# Epoch 14/20: 100% 313/313 [00:11<00:00, 28.19it/s, loss=0.258]
# Epoch 15/20: 100% 313/313 [00:10<00:00, 28.86it/s, loss=0.21]
# Epoch 16/20: 100% 313/313 [00:10<00:00, 28.79it/s, loss=0.21]
# Epoch 17/20: 100% 313/313 [00:10<00:00, 30.90it/s, loss=0.231]
# Epoch 18/20: 100% 313/313 [00:10<00:00, 28.86it/s, loss=0.237]
# Epoch 19/20: 100% 313/313 [00:10<00:00, 28.89it/s, loss=0.198]
# Epoch 20/20: 100% 313/313 [00:10<00:00, 28.62it/s, loss=0.177]
# EEG model saved to /content/drive/MyDrive/ecg_denoiser_hackathon/models2/eeg_denoiser_self_supervised_refactored.pth
#
# ✅ All EEG model training complete!

# %%
# ---
# [Step 3/3] VALIDATION: Run all EEG validation tasks
# ---
print("\n--- [Step 3/3] Running all EEG validations ---")

# --- Result File Paths ---
OUTPUT_VIDEO_PATH = os.path.join(RESULTS_DIR, 'phase1_spatial_comparison_refactored.mp4')
OUTPUT_PSD_PATH = os.path.join(RESULTS_DIR, 'phase2_frequency_comparison_refactored.png')
OUTPUT_UMAP_PATH = os.path.join(RESULTS_DIR, 'phase3_embedding_comparison_refactored.png')
# Use a file with clear seizure activity for the topomap video
TEST_FILE_FOR_VIDEO = os.path.join(DATA_DIR_EEG, "chb01/chb01_03.edf")
OUTPUT_GRADIENT_PLOT_PATH = os.path.join(RESULTS_DIR, 'eeg_gradient_preservation_plot.png')

# --- Phase 1: Spatio-temporal Validation ---
print("\n--- Validating Phase 1: Spatio-temporal Plausibility ---")
# !python3 src/experiments/run_validation.py eeg_spatiotemporal \
    --baseline_model_path "{MODEL_PATH_EEG_BASELINE}" \
    --spatial_model_path "{MODEL_PATH_EEG_SPATIAL}" \
    --test_file_path "{TEST_FILE_FOR_VIDEO}" \
    --output_path "{OUTPUT_VIDEO_PATH}" \
    --output_gradient_plot_path "{OUTPUT_GRADIENT_PLOT_PATH}"
# Out:
# --- [Step 3/3] Running all EEG validations ---
#
# --- Validating Phase 1: Spatio-temporal Plausibility ---
# 2025-09-28 04:51:02.668372: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759035062.690287   19902 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759035062.696512   19902 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759035062.712221   19902 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759035062.712253   19902 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759035062.712257   19902 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759035062.712263   19902 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-28 04:51:02.717000: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# --- Running EEG Validation for: eeg_spatiotemporal ---
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Generating topography video...
# Generating frames: 100% 128/128 [00:34<00:00,  3.70it/s]
# Saving video to /content/drive/MyDrive/ecg_denoiser_hackathon/results2/phase1_spatial_comparison_refactored.mp4
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (2000, 500) to (2000, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Generating gradient preservation plot for channel: FP1-F7...
# Warning: Channel 'FP1-F7' not found. Defaulting to first channel.
# /content/ecg-denoiser-hackathon/src/experiments/run_validation.py:165: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /content/ecg-denoiser-hackathon/src/experiments/run_validation.py:166: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig(output_path)
# ✅ Gradient plot saved to: /content/drive/MyDrive/ecg_denoiser_hackathon/results2/eeg_gradient_preservation_plot.png

# %%
# --- Phase 2: Frequency Validation ---
print("\n--- Validating Phase 2: Frequency-Specific Preservation ---")
# !python3 src/experiments/run_validation.py eeg_frequency \
    --baseline_model_path "{MODEL_PATH_EEG_BASELINE}" \
    --frequency_model_path "{MODEL_PATH_EEG_FREQ}" \
    --data_dir "{DATA_DIR_EEG}" \
    --output_path "{OUTPUT_PSD_PATH}"
# Out:
# --- Validating Phase 2: Frequency-Specific Preservation ---
# 2025-09-28 04:26:44.106475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759033604.140027   13530 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759033604.150022   13530 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759033604.178047   13530 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759033604.178638   13530 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759033604.178659   13530 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759033604.178667   13530 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-28 04:26:44.185886: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# --- Running EEG Validation for: eeg_frequency ---
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Saving PSD plot to /content/drive/MyDrive/ecg_denoiser_hackathon/results2/phase2_frequency_comparison_refactored.png

# %%
# --- Phase 3: Unsupervised Validation ---
print("\n--- Validating Phase 3: Unsupervised Discovery ---")
# !python3 src/experiments/run_validation.py eeg_unsupervised \
    --model_path "{MODEL_PATH_EEG_SS}" \
    --data_dir "{DATA_DIR_EEG}" \
    --output_path "{OUTPUT_UMAP_PATH}"

print("\n\n✅✅✅ Full EEG Study Complete! ✅✅✅")
print("Displaying final plots:")

if os.path.exists(OUTPUT_PSD_PATH):
    print("\n--- Phase 2: PSD Plot ---")
    display(Image(filename=OUTPUT_PSD_PATH))
else:
    print(f"ERROR: {OUTPUT_PSD_PATH} not found.")

if os.path.exists(OUTPUT_UMAP_PATH):
    print("\n--- Phase 3: UMAP Embedding Plot ---")
    display(Image(filename=OUTPUT_UMAP_PATH))
else:
    print(f"ERROR: {OUTPUT_UMAP_PATH} not found.")

print(f"\nPhase 1 video saved to: {OUTPUT_VIDEO_PATH}")
# Out:
# --- Validating Phase 3: Unsupervised Discovery ---
# 2025-09-28 04:36:30.352987: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759034190.373162   16236 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759034190.379512   16236 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759034190.394935   16236 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759034190.394960   16236 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759034190.394964   16236 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759034190.394967   16236 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-28 04:36:30.399661: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# --- Running EEG Validation for: eeg_unsupervised ---
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# /content/ecg-denoiser-hackathon/src/stpc/utils/eeg_utils.py:17: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True, exclude=['T8-P8-1'], verbose=False)
# Extracting embeddings...
# 100% 13/13 [00:00<00:00, 30.44it/s]
# Running UMAP...
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Saving embedding plot to /content/drive/MyDrive/ecg_denoiser_hackathon/results2/phase3_embedding_comparison_refactored.png
#
#
# ✅✅✅ Full EEG Study Complete! ✅✅✅
# Displaying final plots:
#
# --- Phase 2: PSD Plot ---
# --- Phase 3: UMAP Embedding Plot ---
# Phase 1 video saved to: /content/drive/MyDrive/ecg_denoiser_hackathon/results2/phase1_spatial_comparison_refactored.mp4
